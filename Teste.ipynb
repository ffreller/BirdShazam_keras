# %%
import pandas as pd
import numpy as np
df = pd.read_csv('1Dropout_1_23.csv')

# %%
df['certo'] = np.where(df.label==df.y_pred, 1, 0)

# %%
len(df.certo)
# Out:
# 97

# %%
df.certo.sum()
# Out:
# 65

# %%
df.certo.sum()/len(df.certo)
# Out:
# 0.6701030927835051

# %%
porcs = []
for especie in df.label.unique():
    d = df[df.label==especie]
    lend = len(d)
    d = [d.certo.sum()/len(d), len(d), especie]
    porcs.append([d,lend, especie])
for porc in sorted(porcs):
    print(porc)
# Out:
# [[0.3333333333333333, 3, 'Myrmophylax_melanura'], 3, 'Myrmophylax_melanura']
# [[0.3333333333333333, 3, 'Sclerurus_scansor'], 3, 'Sclerurus_scansor']
# [[0.3333333333333333, 3, 'Xiphorhynchus_atlanticus'], 3, 'Xiphorhynchus_atlanticus']
# [[0.3333333333333333, 3, 'Xiphorhynchus_tenuirostris'], 3, 'Xiphorhynchus_tenuirostris']
# [[0.42857142857142855, 7, 'Xiphorhynchus_guttatoides'], 7, 'Xiphorhynchus_guttatoides']
# [[0.6, 5, 'Xiphorhynchus_eytoni'], 5, 'Xiphorhynchus_eytoni']
# [[0.625, 8, 'Sittasomus_sylviellus'], 8, 'Sittasomus_sylviellus']
# [[0.6666666666666666, 3, 'Patagioenas_plumbea'], 3, 'Patagioenas_plumbea']
# [[0.6666666666666666, 6, 'Ramphastos_ariel'], 6, 'Ramphastos_ariel']
# [[0.7142857142857143, 7, 'Xiphorhynchus_fuscus'], 7, 'Xiphorhynchus_fuscus']
# [[0.75, 4, 'Cichlocolaptes_holti'], 4, 'Cichlocolaptes_holti']
# [[0.75, 4, 'Trogon_aurantius'], 4, 'Trogon_aurantius']
# [[0.8, 5, 'Crypturellus_obsoletus'], 5, 'Crypturellus_obsoletus']
# ...

# %%
dde = []
for a in df.label.unique():
    d = df[df.label==a]
    lend = len(d)
    d = d.certo.sum()/lend
    dde.append([d,lend, a])
sorted(dde)
# Out:
# [[0.0, 3, 'Microrhopias_bicolor'],
#  [0.25, 4, 'Sclerurus_cearensis'],
#  [0.25, 4, 'Syndactyla_rufosuperciliata'],
#  [0.3333333333333333, 3, 'Myrmophylax_melanura'],
#  [0.3333333333333333, 3, 'Sclerurus_macconnelli'],
#  [0.42857142857142855, 7, 'Xiphorhynchus_fuscus'],
#  [0.6, 5, 'Ramphastos_ariel'],
#  [0.6, 5, 'Xiphorhynchus_eytoni'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_atlanticus'],
#  [0.7142857142857143, 7, 'Xiphorhynchus_guttatoides'],
#  [0.875, 8, 'Sittasomus_sylviellus'],
#  [1.0, 3, 'Brotogeris_chiriri'],
#  [1.0, 3, 'Crypturellus_albigularis'],
#  [1.0, 3, 'Patagioenas_plumbea'],
#  [1.0, 3, 'Pygiptila_stellaris'],
#  [1.0, 3, 'Sclerurus_scansor'],
#  [1.0, 3, 'Xiphorhynchus_tenuirostris'],
#  [1.0, 4, 'Cichlocolaptes_holti'],
#  [1.0, 4, 'Phaethornis_eurynome'],
#  [1.0, 4, 'Trogon_aurantius'],
#  [1.0, 4, 'Trogon_chrysochloros'],
#  [1.0, 5, 'Crypturellus_obsoletus'],
#  [1.0, 6, 'Megascops_usta']]

# %%
dde = []
for a in df.label.unique():
    d = df[df.label==a]
    lend = len(d)
    d = d.certo.sum()/lend
    dde.append([d,lend, a])
sorted(dde)
# Out:
# [[0.0, 3, 'Microrhopias_bicolor'],
#  [0.25, 4, 'Sclerurus_cearensis'],
#  [0.25, 4, 'Syndactyla_rufosuperciliata'],
#  [0.3333333333333333, 3, 'Myrmophylax_melanura'],
#  [0.3333333333333333, 3, 'Sclerurus_macconnelli'],
#  [0.42857142857142855, 7, 'Xiphorhynchus_fuscus'],
#  [0.6, 5, 'Ramphastos_ariel'],
#  [0.6, 5, 'Xiphorhynchus_eytoni'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_atlanticus'],
#  [0.7142857142857143, 7, 'Xiphorhynchus_guttatoides'],
#  [0.875, 8, 'Sittasomus_sylviellus'],
#  [1.0, 3, 'Brotogeris_chiriri'],
#  [1.0, 3, 'Crypturellus_albigularis'],
#  [1.0, 3, 'Patagioenas_plumbea'],
#  [1.0, 3, 'Pygiptila_stellaris'],
#  [1.0, 3, 'Sclerurus_scansor'],
#  [1.0, 3, 'Xiphorhynchus_tenuirostris'],
#  [1.0, 4, 'Cichlocolaptes_holti'],
#  [1.0, 4, 'Phaethornis_eurynome'],
#  [1.0, 4, 'Trogon_aurantius'],
#  [1.0, 4, 'Trogon_chrysochloros'],
#  [1.0, 5, 'Crypturellus_obsoletus'],
#  [1.0, 6, 'Megascops_usta']]

# %%
dde = []
for a in df.label.unique():
    d = df[df.label==a]
    lend = len(d)
    d = d.certo.sum()/lend
    dde.append([d,lend, a])
sorted(dde)
# Out:
# [[0.0, 4, 'Sclerurus_cearensis'],
#  [0.0, 4, 'Syndactyla_rufosuperciliata'],
#  [0.3333333333333333, 3, 'Microrhopias_bicolor'],
#  [0.3333333333333333, 3, 'Myrmophylax_melanura'],
#  [0.3333333333333333, 3, 'Pygiptila_stellaris'],
#  [0.3333333333333333, 3, 'Sclerurus_macconnelli'],
#  [0.4, 5, 'Xiphorhynchus_eytoni'],
#  [0.42857142857142855, 7, 'Xiphorhynchus_fuscus'],
#  [0.6, 5, 'Ramphastos_ariel'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_atlanticus'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_tenuirostris'],
#  [0.7142857142857143, 7, 'Xiphorhynchus_guttatoides'],
#  [0.75, 4, 'Cichlocolaptes_holti'],
#  [0.75, 4, 'Trogon_aurantius'],
#  [0.875, 8, 'Sittasomus_sylviellus'],
#  [1.0, 3, 'Brotogeris_chiriri'],
#  [1.0, 3, 'Crypturellus_albigularis'],
#  [1.0, 3, 'Patagioenas_plumbea'],
#  [1.0, 3, 'Sclerurus_scansor'],
#  [1.0, 4, 'Phaethornis_eurynome'],
#  [1.0, 4, 'Trogon_chrysochloros'],
#  [1.0, 5, 'Crypturellus_obsoletus'],
#  [1.0, 6, 'Megascops_usta']]

# %%
dde = []
for a in df.label.unique():
    d = df[df.label==a]
    lend = len(d)
    d = d.certo.sum()/lend
    dde.append([d,lend, a])
sorted(dde)
# Out:
# [[0.0, 3, 'Microrhopias_bicolor'],
#  [0.0, 4, 'Sclerurus_cearensis'],
#  [0.0, 4, 'Syndactyla_rufosuperciliata'],
#  [0.2857142857142857, 7, 'Xiphorhynchus_fuscus'],
#  [0.3333333333333333, 3, 'Myrmophylax_melanura'],
#  [0.3333333333333333, 3, 'Pygiptila_stellaris'],
#  [0.3333333333333333, 3, 'Sclerurus_macconnelli'],
#  [0.6, 5, 'Xiphorhynchus_eytoni'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_atlanticus'],
#  [0.6666666666666666, 3, 'Xiphorhynchus_tenuirostris'],
#  [0.7142857142857143, 7, 'Xiphorhynchus_guttatoides'],
#  [0.8, 5, 'Ramphastos_ariel'],
#  [0.875, 8, 'Sittasomus_sylviellus'],
#  [1.0, 3, 'Brotogeris_chiriri'],
#  [1.0, 3, 'Crypturellus_albigularis'],
#  [1.0, 3, 'Patagioenas_plumbea'],
#  [1.0, 3, 'Sclerurus_scansor'],
#  [1.0, 4, 'Cichlocolaptes_holti'],
#  [1.0, 4, 'Phaethornis_eurynome'],
#  [1.0, 4, 'Trogon_aurantius'],
#  [1.0, 4, 'Trogon_chrysochloros'],
#  [1.0, 5, 'Crypturellus_obsoletus'],
#  [1.0, 6, 'Megascops_usta']]

# %%
dde = []
for a in df.label.unique():
    d = df[df.label==a]
    lend = len(d)
    d = d.certo.sum()/lend
    dde.append([d,lend, a])
sorted(dde)
# Out:
# [[0.0, 3, 'Microrhopias_bicolor'],
#  [0.0, 4, 'Sclerurus_cearensis'],
#  [0.0, 4, 'Syndactyla_rufosuperciliata'],
#  [0.2857142857142857, 7, 'Xiphorhynchus_fuscus'],
#  [0.3333333333333333, 3, 'Crypturellus_albigularis'],
#  [0.3333333333333333, 3, 'Myrmophylax_melanura'],
#  [0.3333333333333333, 3, 'Pygiptila_stellaris'],
#  [0.3333333333333333, 3, 'Sclerurus_macconnelli'],
#  [0.3333333333333333, 3, 'Xiphorhynchus_atlanticus'],
#  [0.5, 4, 'Cichlocolaptes_holti'],
#  [0.5714285714285714, 7, 'Xiphorhynchus_guttatoides'],
#  [0.6, 5, 'Ramphastos_ariel'],
#  [0.6, 5, 'Xiphorhynchus_eytoni'],
#  [0.6666666666666666, 3, 'Sclerurus_scansor'],
#  [0.75, 4, 'Phaethornis_eurynome'],
#  [0.75, 4, 'Trogon_chrysochloros'],
#  [0.875, 8, 'Sittasomus_sylviellus'],
#  [1.0, 3, 'Brotogeris_chiriri'],
#  [1.0, 3, 'Patagioenas_plumbea'],
#  [1.0, 3, 'Xiphorhynchus_tenuirostris'],
#  [1.0, 4, 'Trogon_aurantius'],
#  [1.0, 5, 'Crypturellus_obsoletus'],
#  [1.0, 6, 'Megascops_usta']]

# %%
errado = df[df.certo==0]
errado
# Out:
#                                             fname  \
# 0   9f0acb1b2547343b53115635eb119aca_filtrado.wav
# 3   7b5c641d9a89adb5e306cbb1de77df76_filtrado.wav
# 5   10e9dce0ae61491093982b884a95bba5_filtrado.wav
# 6   859a686b42eac9cfd3fed1c2104319a4_filtrado.wav
# 7   704e5d6faa36b1a067823f0cdb0339c9_filtrado.wav
# 10  bb2df0397673b7e9d1dbca72861f14b6_filtrado.wav
# 14  832d08436b313f2cb03ce3328a751b1f_filtrado.wav
# 16  6bb6ba1a60158bc0db0188d8a3c93b0c_filtrado.wav
# 17   cba413caddaf8708aed0cb7a6d1a8c2_filtrado.wav
# 20  80cf5c7f8d686c4e83f90874daa6d4d2_filtrado.wav
# 23  c4bfefe71b7212af6df72857041ceb8d_filtrado.wav
# 24  c5b6d417faa71ccf2f23ae950509d171_filtrado.wav
# 28  58d4aca99d95ea709f5f1dcf39f97121_filtrado.wav
# 30  7fea8f2cb46584c60e14f899c692f707_filtrado.wav
# 34  acd549b759f6e235815dee904b849e30_filtrado.wav
# 35  5188c41aafb17d53189cc2b49d2b33f8_filtrado.wav
# 37  1d15fad55bd37683260639cc78c3301d_filtrado.wav
# 39  9145b8e7adf797eed19bf63f3d176ab6_filtrado.wav
# ...

# %%
errado.label.value_counts()

# yrmophylax_melanura
# Out:
# Xiphorhynchus_fuscus           5
# Sclerurus_cearensis            4
# Syndactyla_rufosuperciliata    4
# Microrhopias_bicolor           3
# Xiphorhynchus_guttatoides      3
# Crypturellus_albigularis       2
# Myrmophylax_melanura           2
# Ramphastos_ariel               2
# Sclerurus_macconnelli          2
# Xiphorhynchus_atlanticus       2
# Xiphorhynchus_eytoni           2
# Cichlocolaptes_holti           2
# Pygiptila_stellaris            2
# Sittasomus_sylviellus          1
# Phaethornis_eurynome           1
# Sclerurus_scansor              1
# Trogon_chrysochloros           1
# Name: label, dtype: int64

# %%
df.label.value_counts()
# Out:
# Sittasomus_sylviellus          8
# Xiphorhynchus_fuscus           7
# Xiphorhynchus_guttatoides      7
# Megascops_usta                 6
# Ramphastos_ariel               5
# Crypturellus_obsoletus         5
# Xiphorhynchus_eytoni           5
# Cichlocolaptes_holti           4
# Trogon_aurantius               4
# Trogon_chrysochloros           4
# Syndactyla_rufosuperciliata    4
# Phaethornis_eurynome           4
# Sclerurus_cearensis            4
# Sclerurus_scansor              3
# Sclerurus_macconnelli          3
# Patagioenas_plumbea            3
# Brotogeris_chiriri             3
# Xiphorhynchus_atlanticus       3
# Crypturellus_albigularis       3
# Pygiptila_stellaris            3
# Microrhopias_bicolor           3
# Xiphorhynchus_tenuirostris     3
# Myrmophylax_melanura           3
# Name: label, dtype: int64

# %%
# # for er in errado.index:
# e = errado.iloc[:, 3:].loc[[4]]
# sorted(e.values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-d092b52946dd> in <module>
#       1 # for er in errado.index:
# ----> 2 e = errado.iloc[:, 3:].loc[[4]]
#       3 sorted(e.values)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1764
#    1765             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1766             return self._getitem_axis(maybe_callable, axis=axis)
#    1767
#    1768     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1950                     raise ValueError("Cannot index with multidimensional key")
#    1951
# -> 1952                 return self._getitem_iterable(key, axis=axis)
#    1953
#    1954             # nested tuple slicing
#
# ...

# %%
l = []
for i in errado.index:
    ind = np.argsort(np.max(errado.iloc[:, 3:].loc[[i]], axis=0))[-2]
    a = errado.iloc[:, ind+3].loc[[i]]
    l.append(a.name)

# %%
errado['segundo'] = l
errado['seg_certo'] = np.where(errado.label==errado.segundo, 1, 0)

# %%
errado.seg_certo.sum()/len(errado)
# Out:
# 0.38461538461538464

# %%
l = []

for i in df.index:
    li = df.loc[i]
    yp = li['y_pred']
    yp = li[yp]
    l.append(yp)
np.mean(l)
# Out:
# 0.5016215575724533

# %%
for a in ['Myrmophylax_melanura','Syndactyla_rufosuperciliata', 'Xiphorhynchus_fuscus']:
    print(a, len(errado[errado.label==a]))
# Out:
# Myrmophylax_melanura 2
# Syndactyla_rufosuperciliata 4
# Xiphorhynchus_fuscus 5

# %%
def event_probability(event_outcomes, sample_space):
    probability = (event_outcomes / sample_space)
    return probability
prob = event_probability(1, 23)
prob*96
# Out:
# 4.173913043478261
